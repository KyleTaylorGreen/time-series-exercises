# %%
import pandas as pd
import all_individual_stats
import env
import api_exp
# Out:
# ['NA1_4035079692_lobby.csv', 'NA1_4035079700_histories.csv', 'NA1_4035079686_lobby.csv', 'NA1_4035079668_lobby.csv', 'NA1_4035079665_lobby.csv', 'NA1_4035079613_lobby.csv', 'NA1_4035079604_histories.csv', 'NA1_4035079613_histories.csv', 'NA1_4035079733_histories.csv', 'NA1_4035079696_histories.csv', 'NA1_4035079692_histories.csv', 'NA1_4035079733_lobby.csv', 'NA1_4035079718_histories.csv', 'NA1_4035079666_histories.csv', 'NA1_4035079696_lobby.csv', 'NA1_4035079604_lobby.csv', 'NA1_4035079665_histories.csv', 'NA1_4035079700_lobby.csv', 'NA1_4035079686_histories.csv', 'NA1_4169245913_lobby.csv', 'NA1_4169245913_histories.csv', 'NA1_4035079718_lobby.csv', 'NA1_4035079668_histories.csv', 'NA1_4035079666_lobby.csv']

# %%
all_individual_stats.time_columns()
# Out:
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#            ...
# 685             NaN
# 686             NaN
# 687    1.641211e+12
# 688    1.640994e+12
# 689    1.640992e+12
# Name: game_end, Length: 690, dtype: float64
#                                                  puuid summoner_name  \
# 555  ZH38E3xWL7EiXyadzmpRp0IxECEThdbCPAEGjN9WfHf39c...    martygabes
# 556  ZH38E3xWL7EiXyadzmpRp0IxECEThdbCPAEGjN9WfHf39c...    martygabes
# 557  ZH38E3xWL7EiXyadzmpRp0IxECEThdbCPAEGjN9WfHf39c...    martygabes
# 558  ZH38E3xWL7EiXyadzmpRp0IxECEThdbCPAEGjN9WfHf39c...    martygabes
# 559  ZH38E3xWL7EiXyadzmpRp0IxECEThdbCPAEGjN9WfHf39c...    martygabes
# ..                                                 ...           ...
# 40   HIDfXP40aq6LMFjBQ-Qsp0Dpe6ERezDkErU83CEhlypNQ1...       Cheet0h
# 41   HIDfXP40aq6LMFjBQ-Qsp0Dpe6ERezDkErU83CEhlypNQ1...       Cheet0h
# 42   HIDfXP40aq6LMFjBQ-Qsp0Dpe6ERezDkErU83CEhlypNQ1...       Cheet0h
# ...
