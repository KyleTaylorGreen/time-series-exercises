# %%
import api_exp
import itertools
import numpy as np
import pandas as pd
import cassiopeia
import env
import requests
import time
import os

# %load_ext autoreload
# %autoreload 2

# %%
match = api_exp.main('NA1_4169229565')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/sg/59gwvnj90xd4dcq4zxv_tkc80000gn/T/ipykernel_3306/3022687075.py in <module>
# ----> 1 match = api_exp.main('NA1_4169229565')
#
# ~/codeup-data-science/time-series-exercises/api_exp.py in main(basic_match_id)
#     213
#     214 def main(basic_match_id):
# --> 215     match_info = Match(basic_match_id)
#     216
#     217     return match_info
#
# ~/codeup-data-science/time-series-exercises/api_exp.py in __init__(self, matchid)
#     108             summoner = requests.get(f'https://na1.api.riotgames.com/lol/summoner/v4/summoners/by-puuid/{puuid}', headers=env.headers).json()
#     109             if PlayerAtTimeOfGame(puuid, self).games_before_match:
# --> 110                 previous_game_id = PlayerAtTimeOfGame(puuid, self).games_before_match
#     111                 print(previous_game_id)
#     112             else:
#
# ~/codeup-data-science/time-series-exercises/api_exp.py in __init__(self, puuid, match)
#     201         self.matchid = match.matchid
#     202         self.creation = int(self.match_data[match.matchid]['info']['gameCreation'] / 1000)
# --> 203         self.games_before_match = self.most_recent_game()
#     204
#     205     def get_games_before_current_game(self, count=100):
#
# ~/codeup-data-science/time-series-exercises/api_exp.py in most_recent_game(self, count)
#     210
#     211     def most_recent_game(self, count=1):
# --> 212         return self.get_games_before_current_game(count=count)
#     213
#     214 def main(basic_match_id):
#
# ~/codeup-data-science/time-series-exercises/api_exp.py in get_games_before_current_game(self, count)
#     205     def get_games_before_current_game(self, count=100):
#     206         limiting_time = self.creation - 1
# --> 207         response = requests.get(f'https://americas.api.riotgames.com/lol/match/v5/matches/by-puuid/{self.puuid}/ids?endTime={limiting_time}&queue=420&start=0&count={count}', headers=env.headers).json()
#     208
#     209         return response
#
# /usr/local/anaconda3/lib/python3.9/site-packages/requests/api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /usr/local/anaconda3/lib/python3.9/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /usr/local/anaconda3/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# /usr/local/anaconda3/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# /usr/local/anaconda3/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# /usr/local/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# /usr/local/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/anaconda3/lib/python3.9/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /usr/local/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# /usr/local/anaconda3/lib/python3.9/http/client.py in getresponse(self)
#    1369         try:
#    1370             try:
# -> 1371                 response.begin()
#    1372             except ConnectionError:
#    1373                 self.close()
#
# /usr/local/anaconda3/lib/python3.9/http/client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# /usr/local/anaconda3/lib/python3.9/http/client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# /usr/local/anaconda3/lib/python3.9/socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# /usr/local/anaconda3/lib/python3.9/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# /usr/local/anaconda3/lib/python3.9/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
match.game_history_dict

# %%
df = match.player_stats

# %%
df.time_since_last_game = round(df.time_since_last_game)

# %%
df['is_session'] = df.time_since_last_game < 46
df

# %%
for val in match.game_history_dict.values():
    print(len(val))

# %%
def get_stat_histories(df, match_obj, filename, start_id = "", game_info=[], stopped=0, start=0):
    first_loop = True
    ids = list(match_obj.game_history_dict.keys())
    #print(ids)
    
    
    cum_sum = np.cumsum([len(val) for val in match_obj.game_history_dict.values()])
    games = [val for val in match_obj.game_history_dict.values()]
    for i, num in enumerate(cum_sum):
        #print(df.shape[0]-num)
        if df.shape[0]-num < 0:
            index_num = i
            id_start = ids.index(ids[i])
            start = df.shape[0]-num
            #print(id_start)
            break
        else:
            id_start = 0
    
    if start_id:
        id_start = ids.index(start_id)
        #print(id_start)

    for puuid in ids[id_start:]:
        #print(ids[id_start])
        if first_loop:
            counter = start
        else:
            counter = 0
        #print(counter)
        for i, game in enumerate(match_obj.game_history_dict[puuid][counter:]):
            
            if game != '0' and game != 0:
                r = requests.get(f'https://americas.api.riotgames.com/lol/match/v5/matches/{game}', headers=env.headers)
                response = r.json()
                time.sleep(1.125)

                try:
                    for participant in response['info']['participants']:
                        #print(response['info']['participants'])

                        if participant['puuid'] == puuid:  
                            try:
                                game_info.append({
                                    'puuid': puuid,
                                    'summoner_name': match_obj.puuid_to_summoner[puuid],
                                    'game_id': game,
                                    'champion_id': participant['championId'],
                                    'champion_name': participant['championName'],
                                    'team_pos': participant['teamPosition'],
                                    'win': participant['win'],
                                    'game_start': response['info']['gameStartTimestamp'],
                                    'game_end': response['info']['gameEndTimestamp'],
                                    'game_duration': response['info']['gameDuration'],
                                    'team': participant['teamId']


                                })
                            except:
                                try:
                                    game_info.append({
                                        'puuid': puuid,
                                        'summoner_name': match_obj.puuid_to_summoner[puuid],
                                        'game_id': game,
                                        'champion_id': participant['championId'],
                                        'champion_name': participant['championName'],
                                        'team_pos': participant['teamPosition'],
                                        'win': participant['win'],
                                        'game_start': response['info']['gameStartTimestamp'],
                                        'game_end': response['info']['gameEndedInSurrender'],
                                        'game_duration': response['info']['gameDuration'],
                                        'team': participant['teamId']



                                    })
                                except:
                                    game_info.append({
                                        'puuid': puuid,
                                        'summoner_name': match_obj.puuid_to_summoner[puuid],
                                        'game_id': game,
                                        'champion_id': participant['championId'],
                                        'champion_name': participant['championName'],
                                        'team_pos': participant['teamPosition'],
                                        'win': participant['win'],
                                        'game_start': response['info']['gameStartTimestamp'],
                                        'game_duration': response['info']['gameDuration'],
                                        'team': participant['teamId']
                                    })

                            first_loop = False
                            df = pd.concat([df, pd.DataFrame(game_info)])
                            df = df.drop_duplicates()
                            df.to_csv(filename, index=False)

                    counter+= 1
                    print(f'\r{counter} of {len(match_obj.game_history_dict[puuid])} complete\
                    current_id :{puuid}, response: {r.status_code}', end='')

                except KeyError:
                    print(response)
                    stopped+=1
                    if stopped==2:
                        print('stopped')
                        df = pd.concat([df, pd.DataFrame(game_info)])
                        df = df.drop_duplicates()
                        df.to_csv(filename, index=False)
                        return df
                    print(f'we stopped at {counter}')
                    time.sleep(120)
                    if counter == len(game_info):
                        print(f'We can start over at index {counter}')
                    if counter == len(game_info) -1:
                        print(f'Start over at {counter}')
                    df = pd.concat([df, pd.DataFrame(game_info)])
                    df = df.drop_duplicates()
                    df.to_csv(filename, index=False)
                    
                    get_stat_histories(df, match_obj, filename, start_id=puuid, game_info=game_info, stopped=stopped, start=i)
                
                except KeyboardInterrupt:
                    return df
                

    return pd.DataFrame(game_info)

# %%
df = pd.read_csv('checkpoint_stats.csv')
df = get_stat_histories(df, match, filename)

# %%
df = pd.read_csv('checkpoint_stats.csv')
df.shape

# %%
df.head()

# %%
match2 = api_exp.main('NA1_4169245913')

# %%
def lobby_and_player_stats(match_id):
    lobby = f'riot_api_data/{match_id}_lobby.csv'
    histories = f'riot_api_data/{match_id}_histories.csv'

    match = api_exp.main(match_id)
    df = match.player_stats
    #df.last_100_games = df.last_100_games.astype('object')
    df.time_since_last_game = round(df.time_since_last_game)
    df['is_session'] = df.time_since_last_game < 46

    df.to_csv(lobby, index=False) 
    df = pd.read_csv(lobby)
    #print(df)
    time.sleep(1)
    
    if os.path.isfile(histories):
        player_stats = pd.read_csv(histories)
    else:
        player_stats = pd.DataFrame()
        
    
    player_stats = get_stat_histories(player_stats, match, filename=histories)
        
    return df, player_stats

# %%
lobby_and_player_stats('NA1_4169245913')

# %%
game_nums = [4169229565, 4169245913, 4035079604, 4035079613, 4035079665, 4035079666, 4035079668, 4035079686, 4035079692, 4035079696, 4035079700, 4035079718, 4035079733, 4035089527, 4035089567, 4035089568, 4035089573, 4035089579, 4035089582, 4035089606, 4035089614, 4035089624, 4035089626, 4035089632, 4035089659, 4035089661, 4035089662, 4035089666, 4035089690, 4035089707, 4035089711, 4035089723, 4035089726, 4035098534, 4035098537, 4035098619, 4035098637, 4035098655, 4035098658, 4035098660, 4035098675, 4035098702, 4035098709, 4035098711, 4035098724, 4035098732, 4035098733, 4035098734, 4035098778, 4035098785, 4035098786, 4035098799, 4035098805, 4035098818, 4035098855, 4035098860, 4035098870, 4035098873, 4035098879, 4035098884, 4035098890, 4035098893, 4035098897, 4035098898, 4035098913, 4035098925, 4035098937, 4035098938, 4035098957, 4035098967, 4035098968, 4035098977, 4035098999, 4035099000, 4035099001, 4035099011, 4035099026, 4035099035, 4035099036, 4035099037, 4035099057, 4035099061, 4035099064, 4035099065, 4035099069, 4035099089, 4035099107, 4035099109, 4035099114, 4035099129, 4035099132, 4035099133, 4035099162, 4035099172, 4035099182, 4035099192, 4035099203, 4035099220, 4035099226, 4035099230, 4035099234, 4035099239, 4035099242, 4035099246, 4035099247, 4035099256, 4035099257, 4035099262, 4035099279, 4035099329, 4035099335, 4035099363, 4035099409, 4035099421, 4035099425, 4035099437, 4035099446, 4035099447, 4035099456, 4035099458, 4035099496, 4035099508, 4035099514, 4035099519, 4035099527, 4035099540, 4035099552, 4035099561, 4035099570, 4035099578, 4035099585, 4035099593, 4035099606, 4035099619, 4035099623, 4035099626, 4035099643, 4035099652, 4035099674, 4035099694, 4035099705, 4035099710, 4035099721, 4035099731, 4035099734, 4035108167, 4035108182, 4035108202, 4035108225, 4035108251, 4035108252, 4035108255, 4035108260, 4035108265, 4035108271, 4035108291, 4035108299, 4035108311, 4035108330, 4035108345, 4035108355, 4035108366, 4035108372, 4035108405]
game_ids= ['NA1_'+str(num) for num in game_nums]
#for a_game in game_ids:
#    try:
#        lobby_and_player_stats(a_game)
#    except:
#        print(a_game)

# %%
error_num = 4169229565


game_nums.index(error_num)
gamma = ['NA1_'+str(num) for num in game_nums[game_nums.index(error_num)+1:]]
for gam in gamma:

    print('sleeping')
    print(gam)
    time.sleep(30)
    lobby_and_player_stats(gam)
# Out:
# sleeping
# NA1_4169245913
# ['NA1_4169093061']
# ['NA1_4169243757']
# ['NA1_4168442951']
# ['NA1_4169243388']
# ['NA1_4169253410']
# ['NA1_4168002015']
# ['NA1_4169224551']
# ['NA1_4168522487']
# ['NA1_4168490995']
# 10 of 72 complete                    current_id :jiIwCSuTb05fLnt1jXeuUxy8xy6wWlQqrlpkYjIrd0M__b3RaubJdnIBnL1rYz1rb96KvVOhdjSoDQ, response: 200{'status': {'message': 'Rate limit exceeded', 'status_code': 429}}
# we stopped at 10
# 100 of 100 complete                    current_id :OSNaDSc7gA1g3OymFT6DJqY0dati2BKgHJxBUO3Sj8dLtDPZf6vI3FENud2-PtQQqxN5MW8mUIFNTA, response: 200sleeping
# NA1_4035079604
# ['NA1_4035052279']
# ['NA1_4035044605']
# ['NA1_4035052183']
# ['NA1_4034909084']
# ['NA1_4030108519']
# ['NA1_4035102609']
# ['NA1_4034362684']
# 100 of 100 complete                    current_id :RNwsHQCcKSwzmgphLH5LVsCoI86luWSrifRWkZISZgaBiqiLvWXw9bh2lMaZ74tm0YZ-RQUeLaLgYg, response: 200sleeping
# NA1_4035079613
# ['NA1_4035054725']
# ['NA1_4035074271']
# ['NA1_4018445056']
# ['NA1_4035054725']
# ['NA1_4035093265']
# ['NA1_4035093265']
# ['NA1_4035090900']
# ['NA1_4035090900']
# 28 of 28 complete                    current_id :UtNATFRQXR9HfJ7rmqlRfqWekf5UT-kI8nF5q88E6W4IPdQZOCcSTdSfJ_FSxvdz7ksuCp03zyD32w, response: 200sleeping
# NA1_4035079665
# ['NA1_4035064188']
# ['NA1_4035064188']
# ['NA1_4034813808']
# ['NA1_4035063944']
# ['NA1_4034259722']
# ['NA1_4035063944']
# ['NA1_4035080862']
# ['NA1_4035080862']
# 11 of 11 complete                    current_id :Ieg7EjPkGKjGimXpgMnX0uPftQEAAe4kBkjaU6A4AJyKODzF8sEX9Q1suoTNBppuGegeIFVV0SyF_A, response: 200sleeping
# NA1_4035079666
# ['NA1_4035074954']
# ['NA1_4035090630']
# ['NA1_4035090630']
# ['NA1_4033714820']
# ['NA1_4034218309']
# ['NA1_4034399277']
# ['NA1_4035091647']
# ['NA1_4034900517']
# 100 of 100 complete                    current_id :kFgu52rr2t5cvWyGNxx3EYllRsZC2FOcdd8kdV5E01TglxdqohFXOgFy0578WcufWTrpPN4fSnxjrg, response: 200sleeping
# NA1_4035079668
# ['NA1_4034999049']
# ['NA1_4035076837']
# ['NA1_4035063172']
# ['NA1_4035043919']
# ['NA1_4035045128']
# ['NA1_4035100777']
# ['NA1_4035041777']
# ['NA1_4035075137']
# 51 of 51 complete                    current_id :1JTwGZMhMJqqA24du4No8FD-mcYSH2MwktflLXROt3_kUTMuBKfVvvYTGBV5XaZm2B6oKFnADjoQ_w, response: 200sleeping
# NA1_4035079686
# ['NA1_4035083112']
# ['NA1_4030610898']
# ['NA1_4033973173']
# ['NA1_4035083112']
# ['NA1_4026220320']
# ['NA1_4032868794']
# ['NA1_4025320015']
# ['NA1_4034979294']
# ['NA1_4033677227']
# 4 of 4 complete                    current_id :wE4N7dplqWdP6xRjaMnQ3CQj8XaSFxbDUQeL9V2DpO3VToO_1OILeE2Ta8WcwvOCuPV06x3NrTsUMg, response: 200sleeping
# NA1_4035079692
# ['NA1_4033054496']
# ['NA1_4033846679']
# ['NA1_4034092744']
# ['NA1_4034092744']
# ['NA1_4034936362']
# ['NA1_4035076309']
# ['NA1_4035076309']
# 100 of 100 complete                    current_id :KUFMe66M4ZB6fFMvxvfp43F48dOrhWp5vDlVGx3Oymn6PWpWHn9HAknAr7-nge3Dp5wJJunJ0TG6bQ, response: 200sleeping
# NA1_4035079696
# ['NA1_4035009226']
# ['NA1_4035090888']
# ['NA1_4035043214']
# ['NA1_4021230187']
# ['NA1_4030846690']
# ['NA1_4032679042']
# ['NA1_4031963474']
# ['NA1_4035092026']
# 100 of 100 complete                    current_id :5TtVuhvEzRzE7QXtjU-m84j1VBQDEvjVAa-10QQnaNcCNHCFRhZ8gc1hflEencU1mDiMUNZgikV0aA, response: 200sleeping
# NA1_4035079700
# ['NA1_4032978121']
# ['NA1_4035043714']
# ['NA1_4035043714']
# ['NA1_4034869056']
# ['NA1_4033838485']
# ['NA1_4030419405']
# ['NA1_4033723967']
# 13 of 13 complete                    current_id :MqNDL7qRLEkUHHzTjb8OBfbmK_3gHR4gOA68R1oeBYnZg8AcEbjXiCrL1ZQymCmPGC7vnkPiOUXWNw, response: 200sleeping
# NA1_4035079718
# ['NA1_4034412302']
# ['NA1_4035076066']
# ['NA1_4030987266']
# ['NA1_4035066824']
# ['NA1_4034544288']
# ['NA1_4027618562']
# 22 of 75 complete                    current_id :ZK1imLt_LY4PArF-w-Xdf6GQdzuARp4z0Te_LGtLIrR2_WaRsy4UGU5mCnNAo7X7KpOOenpJqVYWyw, response: 20000{'status': {'message': 'Internal server error', 'status_code': 500}}
# we stopped at 22
# 53 of 75 complete                    current_id :ZK1imLt_LY4PArF-w-Xdf6GQdzuARp4z0Te_LGtLIrR2_WaRsy4UGU5mCnNAo7X7KpOOenpJqVYWyw, response: 200{'status': {'message': 'Internal server error', 'status_code': 500}}
# stopped
# 30 of 75 complete                    current_id :ZK1imLt_LY4PArF-w-Xdf6GQdzuARp4z0Te_LGtLIrR2_WaRsy4UGU5mCnNAo7X7KpOOenpJqVYWyw, response: 200{'status': {'message': 'Service unavailable', 'status_code': 503}}
# stopped
# sleeping
# NA1_4035079733
# ['NA1_4035053994']
# ['NA1_4034939969']
# ['NA1_4035053994']
# ['NA1_4035075177']
# ['NA1_4035052199']
# ['NA1_4035072785']
# ['NA1_4035072785']
# ['NA1_4035045133']
# 100 of 100 complete                    current_id :lxynA93SxqeDddi-UErUYjj6mGSsIHGF1P2TstaYMemDxLD47Ij2VW1wkqjXD19a2QBqITmt8EXJTA, response: 200sleeping
# NA1_4035089527
